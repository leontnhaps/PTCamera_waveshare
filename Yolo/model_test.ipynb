# %%
from ultralytics import YOLO
from pathlib import Path

# 🔧 필요한 경로만 바꿔줘
WEIGHTS = r"runs\detect\train_y8m_ud3\weights\best.pt"
DATA_YAML = r"Red_reflector_detector.v3-annotatae_3_ver.yolov8\data.yaml"
VAL_IMAGES = r"Red_reflector_detector.v3-annotatae_3_ver.yolov8\valid\images"

model = YOLO(WEIGHTS)
print("Loaded:", WEIGHTS)
# Out:
# Loaded: runs\detect\train_y8m_ud3\weights\best.pt

# %%
# 폴더 일괄 추론
model.predict(
    source=r"set_4\images_ud",
    imgsz=832, conf=0.2, iou=0.5,
    device=0, save=True, show=False, name="predict_folder"
)
# Out:
# image 1/481 c:\Users\gmlwn\OneDrive\ \ICon1\\PTCamera_waveshare\dataset\set_4\images_ud\img_t+00_p+000_20250915_165936_750_ud.jpg: 640x832 2 Stickers, 148.2ms
# image 2/481 c:\Users\gmlwn\OneDrive\ \ICon1\\PTCamera_waveshare\dataset\set_4\images_ud\img_t+00_p+010_20250915_165936_046_ud.jpg: 640x832 3 Stickers, 54.7ms
# image 3/481 c:\Users\gmlwn\OneDrive\ \ICon1\\PTCamera_waveshare\dataset\set_4\images_ud\img_t+00_p+020_20250915_165935_343_ud.jpg: 640x832 3 Stickers, 20.7ms
# image 4/481 c:\Users\gmlwn\OneDrive\ \ICon1\\PTCamera_waveshare\dataset\set_4\images_ud\img_t+00_p+030_20250915_165934_755_ud.jpg: 640x832 2 Stickers, 20.8ms
# image 5/481 c:\Users\gmlwn\OneDrive\ \ICon1\\PTCamera_waveshare\dataset\set_4\images_ud\img_t+00_p+040_20250915_165934_128_ud.jpg: 640x832 3 Stickers, 22.1ms
# image 6/481 c:\Users\gmlwn\OneDrive\ \ICon1\\PTCamera_waveshare\dataset\set_4\images_ud\img_t+00_p+050_20250915_165933_425_ud.jpg: 640x832 2 Stickers, 22.5ms
# ...
